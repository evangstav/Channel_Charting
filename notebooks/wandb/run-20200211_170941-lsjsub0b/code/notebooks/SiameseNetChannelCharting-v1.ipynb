# %%
import wandb
wandb.init(project='ChannelCharting')
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/evs/ChannelCharting" target="_blank">https://app.wandb.ai/evs/ChannelCharting</a><br/>
#                 Run page: <a href="https://app.wandb.ai/evs/ChannelCharting/runs/ifb1zyse" target="_blank">https://app.wandb.ai/evs/ChannelCharting/runs/ifb1zyse</a><br/>
# W&B Run: https://app.wandb.ai/evs/ChannelCharting/runs/ifb1zyse

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import sys
sys.path.append("../src")
import data_preparation

# %%
# read data
data = np.load("../Data/RayTracingData/Remcom_4x4_IR_100taps.npy")

# %%
#one sample example
imag_mean = np.mean(np.imag(data))
imag_std = np.std(np.imag(data))
real_mean = np.mean(np.real(data))
real_std = np.std(np.real(data))
one_sample = data[0:2,:,25:75]
one_sample_real = (np.real(one_sample) - real_mean)/real_std
one_sample_imag = (np.imag(one_sample) - imag_mean)/imag_std

# %%
plt.figure(figsize=(16,16))
for i  in range(1, 17):
    plt.subplot(4,4,i)
    plt.plot(one_sample_real[0, i-1, :], label='Real')
    plt.plot(one_sample_imag[0, i-1, :], label='Imaginary')
    plt.legend()

# %%
one_sample_full = np.concatenate([one_sample_real, one_sample_imag], axis=0)

# %%
one_sample_full.shape
# Out:
# (4, 16, 50)

# %% [markdown]
# We observe that a lot of information is contained on the imaginary part of the impulse. So the 16 antennas, we are gong to have 32 'Channels' for our dataset.
# So we will have a training batch of shape [batch_size, 32 , 100].

# %% [markdown]
# # Siamese Neural Network

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Setting up the Custom Dataset

# %%
# undersampling
idces = np.random.randint(0, data.shape[0], int(0.3*data.shape[0]))
data_undersampled = data[idces]

# %%
data_undersampled.shape
# Out:
# (7176, 16, 100)

# %%
data_undersampled.shape
# train test split
train, test= train_test_split(data_undersampled)

# %%
train_dataset = data_preparation.SiameseDataset(train)
scaler = train_dataset.scaler_real, train_dataset.scaler_imag
test_dataset = data_preparation.SiameseDataset(test, scaler)

# %%
plt.figure(figsize=(20,20))
for i  in range(1, 17):
    plt.subplot(4,4,i)
    plt.plot(train_dataset[0][0][i-1, :], label='1_sample')
    #plt.plot(train_dataset[0][1][i-1, :], label='2_sample')
    plt.legend()

# %%
train_dataset.nb_channels()
# Out:
# 32

# %%
class SimpleNN(nn.Module):
    def __init__(self, dropout):
        super(SimpleNN, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=train_dataset.nb_channels(),
                          out_channels=128,
                          kernel_size=16)
        self.bn1 = nn.BatchNorm1d(128)
        self.conv2 = nn.Conv1d(in_channels=128, 
                          out_channels=64,
                          kernel_size=8)
        self.bn2 = nn.BatchNorm1d(64)
        self.conv3 = nn.Conv1d(in_channels=64,
                          out_channels=16,
                          kernel_size=4)
        self.bn3 = nn.BatchNorm1d(16)
        
        f = data_preparation.conv1d_output_size
        self.features = f(f(f(train_dataset.nb_samples(),kernel_size=16),
                                                       kernel_size=8), 
                                                         kernel_size=4)

        
        
        self.lin1 = nn.Linear(in_features= 16 * self.features, out_features=128)
        self.lin2 = nn.Linear(in_features=128, out_features=32)
        self.lin3 = nn.Linear(in_features=32, out_features=8)
        self.lin4 = nn.Linear(in_features=8, out_features=3)
        
        self.dropout = nn.Dropout(p=dropout)
        
    def forward(self, x):
        x = self.bn1(F.relu(self.conv1(x)))
        x = self.bn2(F.relu(self.conv2(x)))
        x = self.bn3(F.relu(self.conv3(x)))
        x = torch.flatten(x, 1)
        x = self.dropout(F.relu(self.lin1(x)))
        x = self.dropout(F.relu(self.lin2(x)))
        x = self.dropout(F.relu(self.lin3(x)))
        
        out = self.lin4(x)
        
        return out

# %%
dropout = 0.3
model = SimpleNN(dropout)
wandb.watch(model)

# %%
def loss_function(x1, x2, y1, y2):
    return torch.sum((torch.dist(x1,x2) - torch.dist(y1, y2))**2/(torch.dist(x1,x2) + 1e-5))

# %%
x1, x2 = train_dataset[0:10][0], train_dataset[0:10][1]
y1, y2 = model(x1), model(x2)

# %% [markdown]
# ## Training

# %%
a = len(test_dataset)/len(train_dataset)
batch_size = 64

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Epoch 36, Training Loss: 103.66082763671875, Validation Loss: 100.70970153808594
# Epoch 37, Training Loss: 384.0879821777344, Validation Loss: 304.4971618652344
# Epoch 38, Training Loss: 86.21578979492188, Validation Loss: 88.43516540527344
# Epoch 39, Training Loss: 133.39340209960938, Validation Loss: 84.23723602294922
# Epoch 40, Training Loss: 124.63308715820312, Validation Loss: 50.14852523803711
# Epoch 41, Training Loss: 72.03773498535156, Validation Loss: 122.66162872314453
# Epoch 42, Training Loss: 66.36884307861328, Validation Loss: 172.97752380371094
# Epoch 43, Training Loss: 444.39410400390625, Validation Loss: 183.25015258789062
# Epoch 44, Training Loss: 286.3835754394531, Validation Loss: 164.1847381591797
# Epoch 45, Training Loss: 164.00833129882812, Validation Loss: 262.4846496582031
# Epoch 46, Training Loss: 101.47686767578125, Validation Loss: 140.66867065429688
# Epoch 47, Training Loss: 54.15125274658203, Validation Loss: 89.08445739746094
# Epoch 48, Training Loss: 105.42098999023438, Validation Loss: 201.4435272216797
# Epoch 49, Training Loss: 114.18264770507812, Validation Loss: 183.02194213867188
# Epoch 50, Training Loss: 60.55610275268555, Validation Loss: 130.91024780273438
# Epoch 51, Training Loss: 186.10678100585938, Validation Loss: 181.09483337402344
# Epoch 52, Training Loss: 85.14270782470703, Validation Loss: 94.22533416748047
# Epoch 53, Training Loss: 66.95320129394531, Validation Loss: 184.84568786621094
# Epoch 54, Training Loss: 138.82989501953125, Validation Loss: 211.69619750976562
# Epoch 55, Training Loss: 82.87410736083984, Validation Loss: 98.22108459472656
# Epoch 56, Training Loss: 89.53985595703125, Validation Loss: 86.01045989990234
# Epoch 57, Training Loss: 140.03515625, Validation Loss: 308.51837158203125
# Epoch 58, Training Loss: 72.42522430419922, Validation Loss: 128.2760009765625
# Epoch 59, Training Loss: 25.66244888305664, Validation Loss: 59.228599548339844
# Epoch 60, Training Loss: 50.229637145996094, Validation Loss: 349.38555908203125

# %% [markdown]
# ## Evaluate results

# %%
rx_positions = np.load("../Data/RayTracingData/Remcom_4x4_rxpos.npy")

# %%
rx_positions
# Out:
# array([[   4.46871614, -159.38421631,    2.        ],
#        [   6.96871614, -159.38421631,    2.        ],
#        [   9.46871614, -159.38421631,    2.        ],
#        ...,
#        [ 464.46871614,  278.11578369,    2.        ],
#        [ 466.96871614,  278.11578369,    2.        ],
#        [ 469.46871614,  278.11578369,    2.        ]])

# %%
example_1= test_dataset[0:1][0]
example_2= test_dataset[11:12][0]

example_1.shape, example_2.shape
# Out:
# (torch.Size([1, 32, 100]), torch.Size([1, 32, 100]))

# %%
example_1_mapping, example_2_mapping = model(example_1), model(example_2)

# %%
example_1_mapping, example_2_mapping
# Out:
# (tensor([[ 1.2289,  0.3474, -0.7273]], grad_fn=<AddmmBackward>),
#  tensor([[ 8.1756,  2.8722, -2.0100]], grad_fn=<AddmmBackward>))

# %%
loss_function(example_1, example_2, example_1_mapping, example_2_mapping)
# Out:
# tensor(2.8037, grad_fn=<SumBackward0>)

# %%
example_1_mapping, example_2_mapping
# Out:
# (tensor([[ 1.2289,  0.3474, -0.7273]], grad_fn=<AddmmBackward>),
#  tensor([[ 8.1756,  2.8722, -2.0100]], grad_fn=<AddmmBackward>))

# %%
mappings = model(test_dataset[:][0]).detach().numpy()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,20))
ax = Axes3D(fig)
ax.scatter(mappings[:,0], mappings[:,1], mappings[:,2], label='Predicted')
ax.legend()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,20))
ax = Axes3D(fig)
ax.scatter(rx_positions[:,0], rx_positions[:,1], rx_positions[:,2], label='True')
ax.legend()
